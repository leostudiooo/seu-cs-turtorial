# %%
Limit[((1+x+x^2)^(1/n)-1)/Sin[2x],x->0]

# %%
Limit[(5x^2-2(1-Cos[x]^2))/(4x^3+3Tan[x]^2),x->0]

# %%
Plot[1/x Sin[1/x],{x,0,1}]

# %%
1/x Sin[1/x]

# %%
WolframAlpha["1/x Sin[1/x]"]
# Out:
# DynamicNamespace[WolframAlphaQueryResults,
#
# >   DynamicModule[{Typeset`q = 1/x Sin[1/x],
#
# >     Typeset`opts =
#
# >      {AppearanceElements ->
#
# >        {Warnings, Assumptions, Brand, Pods, PodMenus, Unsuccessful, Sources}},
#
# >     Typeset`elements =
#
# >      {Warnings, Assumptions, Brand, Pods, PodMenus, Unsuccessful, Sources},
#
# >     Typeset`pod1 =
#
# >      XMLElement[pod, {title -> Input, scanner -> Identity, id -> Input,
#
# >        position -> 100, error -> false, numsubpods -> 1},
#
# >       {XMLElement[subpod, {title -> },
#
# >         {XMLElement[minput, {}, {(1/x) Sin[1/x]}],
#
# >          XMLElement[cell, {compressed -> False, string -> True},
#
# >           {Cell[BoxData[FormBox[TagBox[RowBox[{TagBox[FractionBox[1, x],
#
# >                   PolynomialForm[#1, TraditionalOrder -> False] & ],  ,
#
# >                  RowBox[{sin, (, FractionBox[1, x], )}]}],
#
# ...

# %%
Plot[1/x^2 - 1/(6x^4), {x,0,1}]

# %%
Solve[(1/x Sin[1/x] > a), x]

# %%
Reduce[x^2-2x+1>0,x]

# %%
Limit[(x^2-4)/(2x^2+x),x->Infinity]==1/2
# Out:
# True
